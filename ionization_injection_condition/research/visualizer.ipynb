# %% [markdown]
# ##### Import libs

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import title, show

# %% [markdown]
# ##### Input data

# %%
ctau = [30,40,50,60]
#ion_level = [6,7,8,9,10]
ionization_degree = [,15.82,,22.77]
trapping = [0,0,13.96,0.78,0]

# %% [markdown]
# ##### Plot data

# %%
fig, ax = plt.subplots(figsize=(20,10))

# %%
plt.xlabel("Tau (fs)")
plt.ylabel("Trapping degree (%)", color="blue")
ax.plot(ion_level,trapping,label="Trapping degree", color="blue")
ax.twinx()
plt.xlabel("Ionization niveau")
plt.ylabel("Ionization degree (%)", color="green")
ax.plot(ion_level,ionization_degree,label="Ionization degree", color="green")

legend = ax.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('medium')

for label in legend.get_lines():
    label.set_linewidth(1.5)  # the legend line width
title("Ar8+ -> Ar9+, a0 = 1.2, tau= 30fs-60fs")

# %%
plt.show()

# %%
fig.savefig("trapping_niveau.png")
